# %% [markdown]
# # Identify the consititutive heterochromatin states among the mouse genomce by H3K9me3 signals

# %%
suppressPackageStartupMessages({
    library(tidyverse)
    library(GenomicRanges)
    library(rtracklayer)
    library(tmpRpkg)
})
Sys.setenv("_R_USE_PIPEBIND_" = TRUE)
# change the size of figures shown in jupyter
options(repr.plot.width=10, repr.plot.height=8)

# %%
# * meta# * meta
projd <- here::here()
binSize <- 5000
genomeBind <- file.path(projd, "09.epimem", "out", "genomeBin")
## load blacklist
blfnm <- file.path(projd, "meta", "mm10-blacklist.v2.bed")
blgr <- loadGRfromBed(blfnm, header = TRUE)
blgr
# Out:
# GRanges object with 3434 ranges and 1 metadata column:
#          seqnames            ranges strand | High Signal Region
#             <Rle>         <IRanges>  <Rle> |        <character>
#      [1]    chr10   3218900-3276600      * |    Low Mappability
#      [2]    chr10   3576900-3627700      * |    Low Mappability
#      [3]    chr10   4191100-4197600      * |    Low Mappability
#      [4]    chr10   4613500-4615400      * | High Signal Region
#      [5]    chr10   4761300-4763900      * | High Signal Region
#      ...      ...               ...    ... .                ...
#   [3430]     chrY   6530200-6663200      * | High Signal Region
#   [3431]     chrY   6760200-6835800      * | High Signal Region
#   [3432]     chrY   6984100-8985400      * | High Signal Region
#   [3433]     chrY 10638500-41003800      * | High Signal Region
#   [3434]     chrY 41159200-91744600      * | High Signal Region
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

# %%
# load gtf
mm10 <- import(file.path(projd, "meta", "gencode.vM25.annotation.gtf"))
mm10
table(mm10$gene_type)
# Out:
# GRanges object with 1872052 ranges and 21 metadata columns:
#             seqnames          ranges strand |   source       type     score
#                <Rle>       <IRanges>  <Rle> | <factor>   <factor> <numeric>
#         [1]     chr1 3073253-3074322      + |  HAVANA  gene              NA
#         [2]     chr1 3073253-3074322      + |  HAVANA  transcript        NA
#         [3]     chr1 3073253-3074322      + |  HAVANA  exon              NA
#         [4]     chr1 3102016-3102125      + |  ENSEMBL gene              NA
#         [5]     chr1 3102016-3102125      + |  ENSEMBL transcript        NA
#         ...      ...             ...    ... .      ...        ...       ...
#   [1872048]     chrM     15289-15355      + |  ENSEMBL transcript        NA
#   [1872049]     chrM     15289-15355      + |  ENSEMBL exon              NA
#   [1872050]     chrM     15356-15422      - |  ENSEMBL gene              NA
#   [1872051]     chrM     15356-15422      - |  ENSEMBL transcript        NA
#   [1872052]     chrM     15356-15422      - |  ENSEMBL exon              NA
#                 phase              gene_id   gene_type     gene_name
#             <integer>          <character> <character>   <character>
#         [1]      <NA> ENSMUSG00000102693.1         TEC 4933401J01Rik
#         [2]      <NA> ENSMUSG00000102693.1         TEC 4933401J01Rik
#         [3]      <NA> ENSMUSG00000102693.1         TEC 4933401J01Rik
#         [4]      <NA> ENSMUSG00000064842.1       snRNA       Gm26206
#         [5]      <NA> ENSMUSG00000064842.1       snRNA       Gm26206
#         ...       ...                  ...         ...           ...
#   [1872048]      <NA> ENSMUSG00000064371.1     Mt_tRNA         mt-Tt
#   [1872049]      <NA> ENSMUSG00000064371.1     Mt_tRNA         mt-Tt
#   [1872050]      <NA> ENSMUSG00000064372.1     Mt_tRNA         mt-Tp
#   [1872051]      <NA> ENSMUSG00000064372.1     Mt_tRNA         mt-Tp
#   [1872052]      <NA> ENSMUSG00000064372.1     Mt_tRNA         mt-Tp
#                   level      mgi_id          havana_gene        transcript_id
#             <character> <character>          <character>          <character>
#         [1]           2 MGI:1918292 OTTMUSG00000049935.1                 <NA>
#         [2]           2 MGI:1918292 OTTMUSG00000049935.1 ENSMUST00000193812.1
#         [3]           2 MGI:1918292 OTTMUSG00000049935.1 ENSMUST00000193812.1
#         [4]           3 MGI:5455983                 <NA>                 <NA>
#         [5]           3 MGI:5455983                 <NA> ENSMUST00000082908.1
#         ...         ...         ...                  ...                  ...
#   [1872048]           3  MGI:102473                 <NA> ENSMUST00000082422.1
#   [1872049]           3  MGI:102473                 <NA> ENSMUST00000082422.1
#   [1872050]           3  MGI:102478                 <NA>                 <NA>
#   [1872051]           3  MGI:102478                 <NA> ENSMUST00000082423.1
#   [1872052]           3  MGI:102478                 <NA> ENSMUST00000082423.1
#             transcript_type   transcript_name transcript_support_level
#                 <character>       <character>              <character>
#         [1]            <NA>              <NA>                     <NA>
#         [2]             TEC 4933401J01Rik-201                       NA
#         [3]             TEC 4933401J01Rik-201                       NA
#         [4]            <NA>              <NA>                     <NA>
#         [5]           snRNA       Gm26206-201                       NA
#         ...             ...               ...                      ...
#   [1872048]         Mt_tRNA         mt-Tt-201                       NA
#   [1872049]         Mt_tRNA         mt-Tt-201                       NA
#   [1872050]            <NA>              <NA>                     <NA>
#   [1872051]         Mt_tRNA         mt-Tp-201                       NA
#   [1872052]         Mt_tRNA         mt-Tp-201                       NA
#                     tag    havana_transcript exon_number              exon_id
#             <character>          <character> <character>          <character>
#         [1]        <NA>                 <NA>        <NA>                 <NA>
#         [2]       basic OTTMUST00000127109.1        <NA>                 <NA>
#         [3]       basic OTTMUST00000127109.1           1 ENSMUSE00001343744.1
#         [4]        <NA>                 <NA>        <NA>                 <NA>
#         [5]       basic                 <NA>        <NA>                 <NA>
#         ...         ...                  ...         ...                  ...
#   [1872048]       basic                 <NA>        <NA>                 <NA>
#   [1872049]       basic                 <NA>           1 ENSMUSE00000521549.1
#   [1872050]        <NA>                 <NA>        <NA>                 <NA>
#   [1872051]       basic                 <NA>        <NA>                 <NA>
#   [1872052]       basic                 <NA>           1 ENSMUSE00000521550.1
#              protein_id      ccdsid         ont
#             <character> <character> <character>
#         [1]        <NA>        <NA>        <NA>
#         [2]        <NA>        <NA>        <NA>
#         [3]        <NA>        <NA>        <NA>
#         [4]        <NA>        <NA>        <NA>
#         [5]        <NA>        <NA>        <NA>
#         ...         ...         ...         ...
#   [1872048]        <NA>        <NA>        <NA>
#   [1872049]        <NA>        <NA>        <NA>
#   [1872050]        <NA>        <NA>        <NA>
#   [1872051]        <NA>        <NA>        <NA>
#   [1872052]        <NA>        <NA>        <NA>
#   -------
#   seqinfo: 22 sequences from an unspecified genome; no seqlengths
#           3prime_overlapping_ncRNA                          antisense
#                                 16                              19316
#      bidirectional_promoter_lncRNA                          IG_C_gene
#                               1211                                246
#                    IG_C_pseudogene                          IG_D_gene
#                                  5                                 78
#                    IG_D_pseudogene                          IG_J_gene
#                                  9                                 64
#                         IG_LV_gene                      IG_pseudogene
#                                 22                                  7
#                          IG_V_gene                    IG_V_pseudogene
#                               2000                                587
#                            lincRNA                       macro_lncRNA
#                              40389                                 10
#                              miRNA                           misc_RNA
#                               6606                               1686
#                            Mt_rRNA                            Mt_tRNA
#                                  6                                 66
#             polymorphic_pseudogene               processed_pseudogene
#                               2099                              31103
#               processed_transcript                     protein_coding
#                              11438                            1711899
#                         pseudogene                           ribozyme
#                                271                                 66
#                               rRNA                             scaRNA
#                               1062                                153
#                              scRNA                     sense_intronic
#                                  3                               1305
#                  sense_overlapping                             snoRNA
#                                174                               4521
#                              snRNA                               sRNA
#                               4149                                  6
#                                TEC                          TR_C_gene
#                               9899                                115
#                          TR_D_gene                          TR_J_gene
#                                 18                                292
#                    TR_J_pseudogene                          TR_V_gene
#                                 30                               1350
#                    TR_V_pseudogene   transcribed_processed_pseudogene
#                                115                               2079
#     transcribed_unitary_pseudogene transcribed_unprocessed_pseudogene
#                                659                               4329
#  translated_unprocessed_pseudogene                 unitary_pseudogene
#                                 12                                419
#             unprocessed_pseudogene
#                              12162

# %%
## get TE annotations in the genome
loadRepeatMasker <- function() {
    colnms <- c("bin", "swScore", "milliDiv", "milliDel", "milliIns", "genoName", "genoStart", "genoEnd", 
               "genoLeft", "strand", "repName", "repClass", "repFamliy", "repStart", "repEnd", "repLeft", 
               "id")
    r <- data.table::fread(
        file = file.path(projd, "meta", "mm10.RepeatMasker.txt"), 
        sep = "\t", header = FALSE) |>
      setNames(object = _, nm = colnms)
    return(r)
}
rawTEs <- loadRepeatMasker()
## other heterochromatin annotations

# %%
head(rawTEs)
# Out:
#   bin swScore milliDiv milliDel milliIns genoName genoStart genoEnd genoLeft
# 1 585  463     13        6      17       chr1     10000     10468   -248945954
# 2 585 3612    114      215      13       chr1     10468     11447   -248944975
# 3 585  484    251      132       0       chr1     11504     11675   -248944747
# 4 585  239    294       19      10       chr1     11677     11780   -248944642
# 5 585  318    230       37       0       chr1     15264     15355   -248941067
# 6 585   18    232        0      19       chr1     15797     15849   -248940573
#   strand repName   repClass      repFamliy     repStart repEnd repLeft id
# 1 +      (TAACCC)n Simple_repeat Simple_repeat     1     471     0     1
# 2 -      TAR1      Satellite     telo           -399    1712   483     2
# 3 -      L1MC5a    LINE          L1            -2382     395   199     3
# 4 -      MER5B     DNA           hAT-Charlie     -74     104     1     4
# 5 -      MIR3      SINE          MIR            -119     143    49     5
# 6 +      (TGCTCC)n Simple_repeat Simple_repeat     1      52     0     6

# %% [raw]
# # 1. Calculate the H3K9me3 signals in 5kb-size genome bins
# # 2. Filter black list and sex chromosomes
# # 2. Identify the regions that are show high signals, medium ones, and low signals
#      - The regions should have low H3K27ac, H3K27me3, H3K4me1 signals (at least lower than Q50).
#      - gene body +- 5kb regions should be excluded
# # 3. Overlap with
#      - the annotated TE regions or other known constitutive heterochromatin (positive control)
#      - promoter regions, ATAC-seq peak regions we have identified (negative control)
#      - cross different cell types, are they conservative?

# %%
# * functions
histbwd <- file.path(projd, "09.epimem", "out", "genomeBin")
loadAllHistoneSignals <- function(sc) {
  r1 <- read.csv(file.path(histbwd, paste0(sc, ".H3K9me3.5000.csv")), sep = ",", header = TRUE)
  rownames(r1) <- r1$region
  r2 <- read.csv(file.path(histbwd, paste0(sc, ".H3K27ac_H3K27me3_H3K4me1.5000.csv")), sep = ",", header = TRUE)
  rownames(r2) <- r2$region
  r <- merge(r1, r2, by = "region", all = FALSE)
  return(r)
}

# %%
# analyze one k9 as example
sc <- "326_OPC_NN"
k9 <- loadAllHistoneSignals(sc)
head(k9)
max(k9$H3K9me3)
quantile(k9$H3K9me3, probs = c(0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99, 0.999))
# Out:
#   region                   H3K9me3   H3K27ac   H3K27me3  H3K4me1
# 1 chr1:1-5000              0.0000000 0.0000000 0.0000000 0.0000000
# 2 chr1:100000001-100005000 1.3969261 0.3557545 0.9780488 0.3610463
# 3 chr1:10000001-10005000   0.1817366 0.3313600 1.1783989 0.2195246
# 4 chr1:1000001-1005000     0.0000000 0.0000000 0.0000000 0.0000000
# 5 chr1:100001-105000       0.0000000 0.0000000 0.0000000 0.0000000
# 6 chr1:100005001-100010000 0.6263849 0.2784645 0.7742647 0.2754316
# [1] 90.97491
#       10%       25%       50%       75%       90%       95%       99%     99.9%
# 0.1874992 0.3075027 0.5095049 0.8720211 1.5129094 2.0468474 3.5614128 5.8035416

# %%
# remove blacklist and sex chromosomes

# %%
# The regions should have low H3K27ac, H3K27me3, H3K4me1 signals (at least lower than Q50)
